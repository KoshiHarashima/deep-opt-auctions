# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import sys
import numpy as np
import matplotlib.pyplot as plt

from nets import *
from cfgs import *
from data import *
from clip_ops.clip_ops import *
from trainer import *

# %%
# %matplotlib inline
save_plot = True
plt.rcParams.update({'font.size': 10, 'axes.labelsize': 'x-large'})
D = 201

x = np.linspace(0, 1.0, D)
X_tst = np.stack([v.flatten() for v in np.meshgrid(x,x)], axis = -1)
X_tst = np.expand_dims(X_tst, 1)
X_tst  = X_tst + 2.0
print(X_tst.shape)

cfg = unit_1x2_uniform_23_config.cfg
cfg.test.num_misreports = 1
cfg.test.gd_iter = 0
cfg.test.batch_size = D
cfg.test.num_batches = int(X_tst.shape[0]/cfg.test.batch_size)
cfg.test.save_output = True
# Out:
# (40401, 1, 2)

# %%
Net = unit_net.Net
Generator = uniform_23_generator.Generator
clip_op_lambda = (lambda x: clip_op_23(x))
Trainer = trainer.Trainer

# %%
net = Net(cfg)
generator = Generator(cfg, 'test', X_tst)
m = Trainer(cfg, "test", net, clip_op_lambda)
m.test(generator)
# Out:
# INFO:tensorflow:Restoring parameters from experiments/unit_1x2_uniform_23/model-400000
# 2019-02-02 23:11:51,424:INFO:Restoring parameters from experiments/unit_1x2_uniform_23/model-400000
# 2019-02-02 23:12:01,899:INFO:TEST BATCH-0: t = 10.3224, Revenue: 1.784158, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:01,909:INFO:TEST BATCH-1: t = 10.3277, Revenue: 1.791996, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:01,917:INFO:TEST BATCH-2: t = 10.3327, Revenue: 1.799996, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:01,926:INFO:TEST BATCH-3: t = 10.3376, Revenue: 1.808144, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:01,934:INFO:TEST BATCH-4: t = 10.3424, Revenue: 1.816426, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:01,942:INFO:TEST BATCH-5: t = 10.3471, Revenue: 1.824825, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:01,950:INFO:TEST BATCH-6: t = 10.3518, Revenue: 1.833327, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:01,958:INFO:TEST BATCH-7: t = 10.3564, Revenue: 1.841917, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:01,965:INFO:TEST BATCH-8: t = 10.3609, Revenue: 1.850580, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:01,972:INFO:TEST BATCH-9: t = 10.3651, Revenue: 1.859307, Regret: 0.000011, IRP: 0.000000
# 2019-02-02 23:12:01,980:INFO:TEST BATCH-10: t = 10.3695, Revenue: 1.868082, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:01,987:INFO:TEST BATCH-11: t = 10.3737, Revenue: 1.876896, Regret: 0.000013, IRP: 0.000000
# 2019-02-02 23:12:01,994:INFO:TEST BATCH-12: t = 10.3779, Revenue: 1.885731, Regret: 0.000009, IRP: 0.000000
# 2019-02-02 23:12:02,001:INFO:TEST BATCH-13: t = 10.3821, Revenue: 1.894569, Regret: 0.000011, IRP: 0.000000
# 2019-02-02 23:12:02,008:INFO:TEST BATCH-14: t = 10.3864, Revenue: 1.903387, Regret: 0.000011, IRP: 0.000000
# 2019-02-02 23:12:02,015:INFO:TEST BATCH-15: t = 10.3906, Revenue: 1.912170, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,022:INFO:TEST BATCH-16: t = 10.3948, Revenue: 1.920905, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,029:INFO:TEST BATCH-17: t = 10.3990, Revenue: 1.929595, Regret: 0.000008, IRP: 0.000000
# 2019-02-02 23:12:02,036:INFO:TEST BATCH-18: t = 10.4032, Revenue: 1.938242, Regret: 0.000005, IRP: 0.000000
# 2019-02-02 23:12:02,043:INFO:TEST BATCH-19: t = 10.4075, Revenue: 1.946851, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,050:INFO:TEST BATCH-20: t = 10.4117, Revenue: 1.955427, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,057:INFO:TEST BATCH-21: t = 10.4159, Revenue: 1.963975, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,064:INFO:TEST BATCH-22: t = 10.4201, Revenue: 1.972498, Regret: 0.000017, IRP: 0.000000
# 2019-02-02 23:12:02,071:INFO:TEST BATCH-23: t = 10.4243, Revenue: 1.981000, Regret: 0.000008, IRP: 0.000000
# 2019-02-02 23:12:02,078:INFO:TEST BATCH-24: t = 10.4285, Revenue: 1.989480, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,085:INFO:TEST BATCH-25: t = 10.4327, Revenue: 1.997939, Regret: 0.000003, IRP: 0.000000
# 2019-02-02 23:12:02,092:INFO:TEST BATCH-26: t = 10.4369, Revenue: 2.006373, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,099:INFO:TEST BATCH-27: t = 10.4414, Revenue: 2.014775, Regret: 0.000005, IRP: 0.000000
# 2019-02-02 23:12:02,106:INFO:TEST BATCH-28: t = 10.4456, Revenue: 2.023137, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,114:INFO:TEST BATCH-29: t = 10.4498, Revenue: 2.031446, Regret: 0.000006, IRP: 0.000000
# 2019-02-02 23:12:02,122:INFO:TEST BATCH-30: t = 10.4540, Revenue: 2.039687, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,129:INFO:TEST BATCH-31: t = 10.4586, Revenue: 2.047840, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,137:INFO:TEST BATCH-32: t = 10.4632, Revenue: 2.055882, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,145:INFO:TEST BATCH-33: t = 10.4682, Revenue: 2.063788, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,153:INFO:TEST BATCH-34: t = 10.4734, Revenue: 2.071526, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,160:INFO:TEST BATCH-35: t = 10.4783, Revenue: 2.079063, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,168:INFO:TEST BATCH-36: t = 10.4830, Revenue: 2.086366, Regret: 0.000004, IRP: 0.000000
# 2019-02-02 23:12:02,175:INFO:TEST BATCH-37: t = 10.4873, Revenue: 2.093397, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,190:INFO:TEST BATCH-38: t = 10.4999, Revenue: 2.100122, Regret: 0.000015, IRP: 0.000000
# 2019-02-02 23:12:02,198:INFO:TEST BATCH-39: t = 10.5041, Revenue: 2.106507, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,206:INFO:TEST BATCH-40: t = 10.5083, Revenue: 2.112522, Regret: 0.000008, IRP: 0.000000
# 2019-02-02 23:12:02,213:INFO:TEST BATCH-41: t = 10.5124, Revenue: 2.118145, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,220:INFO:TEST BATCH-42: t = 10.5166, Revenue: 2.123357, Regret: 0.000004, IRP: 0.000000
# 2019-02-02 23:12:02,227:INFO:TEST BATCH-43: t = 10.5207, Revenue: 2.128152, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,234:INFO:TEST BATCH-44: t = 10.5248, Revenue: 2.132529, Regret: 0.000003, IRP: 0.000000
# 2019-02-02 23:12:02,241:INFO:TEST BATCH-45: t = 10.5290, Revenue: 2.136493, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,248:INFO:TEST BATCH-46: t = 10.5331, Revenue: 2.140061, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,255:INFO:TEST BATCH-47: t = 10.5372, Revenue: 2.143249, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,262:INFO:TEST BATCH-48: t = 10.5413, Revenue: 2.146080, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,269:INFO:TEST BATCH-49: t = 10.5454, Revenue: 2.148579, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,276:INFO:TEST BATCH-50: t = 10.5495, Revenue: 2.150772, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,283:INFO:TEST BATCH-51: t = 10.5536, Revenue: 2.152685, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,290:INFO:TEST BATCH-52: t = 10.5577, Revenue: 2.154344, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,297:INFO:TEST BATCH-53: t = 10.5618, Revenue: 2.155773, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,304:INFO:TEST BATCH-54: t = 10.5660, Revenue: 2.156997, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,311:INFO:TEST BATCH-55: t = 10.5701, Revenue: 2.158037, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,319:INFO:TEST BATCH-56: t = 10.5742, Revenue: 2.158914, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,326:INFO:TEST BATCH-57: t = 10.5790, Revenue: 2.159647, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,334:INFO:TEST BATCH-58: t = 10.5837, Revenue: 2.160252, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,341:INFO:TEST BATCH-59: t = 10.5884, Revenue: 2.160745, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,348:INFO:TEST BATCH-60: t = 10.5926, Revenue: 2.161140, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,355:INFO:TEST BATCH-61: t = 10.5970, Revenue: 2.161451, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,363:INFO:TEST BATCH-62: t = 10.6020, Revenue: 2.161689, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,370:INFO:TEST BATCH-63: t = 10.6068, Revenue: 2.161862, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,377:INFO:TEST BATCH-64: t = 10.6111, Revenue: 2.161982, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,384:INFO:TEST BATCH-65: t = 10.6153, Revenue: 2.162055, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,392:INFO:TEST BATCH-66: t = 10.6202, Revenue: 2.162089, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,400:INFO:TEST BATCH-67: t = 10.6255, Revenue: 2.162090, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,407:INFO:TEST BATCH-68: t = 10.6301, Revenue: 2.162065, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,414:INFO:TEST BATCH-69: t = 10.6345, Revenue: 2.162018, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,421:INFO:TEST BATCH-70: t = 10.6390, Revenue: 2.161952, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,428:INFO:TEST BATCH-71: t = 10.6434, Revenue: 2.161873, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,435:INFO:TEST BATCH-72: t = 10.6477, Revenue: 2.161784, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,442:INFO:TEST BATCH-73: t = 10.6522, Revenue: 2.161687, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,449:INFO:TEST BATCH-74: t = 10.6566, Revenue: 2.161586, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,456:INFO:TEST BATCH-75: t = 10.6611, Revenue: 2.161482, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,463:INFO:TEST BATCH-76: t = 10.6655, Revenue: 2.161378, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,470:INFO:TEST BATCH-77: t = 10.6699, Revenue: 2.161275, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,477:INFO:TEST BATCH-78: t = 10.6743, Revenue: 2.161176, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,484:INFO:TEST BATCH-79: t = 10.6788, Revenue: 2.161082, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,491:INFO:TEST BATCH-80: t = 10.6832, Revenue: 2.160993, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,498:INFO:TEST BATCH-81: t = 10.6876, Revenue: 2.160912, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,505:INFO:TEST BATCH-82: t = 10.6922, Revenue: 2.160840, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,512:INFO:TEST BATCH-83: t = 10.6966, Revenue: 2.160777, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,520:INFO:TEST BATCH-84: t = 10.7017, Revenue: 2.160725, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,527:INFO:TEST BATCH-85: t = 10.7067, Revenue: 2.160685, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,535:INFO:TEST BATCH-86: t = 10.7115, Revenue: 2.160657, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,542:INFO:TEST BATCH-87: t = 10.7163, Revenue: 2.160642, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,549:INFO:TEST BATCH-88: t = 10.7206, Revenue: 2.160641, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,556:INFO:TEST BATCH-89: t = 10.7251, Revenue: 2.160655, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,564:INFO:TEST BATCH-90: t = 10.7302, Revenue: 2.160685, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,572:INFO:TEST BATCH-91: t = 10.7351, Revenue: 2.160730, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,579:INFO:TEST BATCH-92: t = 10.7396, Revenue: 2.160792, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,586:INFO:TEST BATCH-93: t = 10.7439, Revenue: 2.160871, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,591:INFO:TEST BATCH-94: t = 10.7470, Revenue: 2.160967, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,596:INFO:TEST BATCH-95: t = 10.7499, Revenue: 2.161081, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,601:INFO:TEST BATCH-96: t = 10.7531, Revenue: 2.161213, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,606:INFO:TEST BATCH-97: t = 10.7561, Revenue: 2.161363, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,612:INFO:TEST BATCH-98: t = 10.7599, Revenue: 2.161531, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,617:INFO:TEST BATCH-99: t = 10.7640, Revenue: 2.161717, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,622:INFO:TEST BATCH-100: t = 10.7686, Revenue: 2.161922, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,627:INFO:TEST BATCH-101: t = 10.7727, Revenue: 2.162145, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,632:INFO:TEST BATCH-102: t = 10.7766, Revenue: 2.162387, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,637:INFO:TEST BATCH-103: t = 10.7798, Revenue: 2.162646, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,642:INFO:TEST BATCH-104: t = 10.7826, Revenue: 2.162924, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,647:INFO:TEST BATCH-105: t = 10.7856, Revenue: 2.163218, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,651:INFO:TEST BATCH-106: t = 10.7884, Revenue: 2.163531, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,656:INFO:TEST BATCH-107: t = 10.7912, Revenue: 2.163861, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,660:INFO:TEST BATCH-108: t = 10.7940, Revenue: 2.164207, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,666:INFO:TEST BATCH-109: t = 10.7979, Revenue: 2.164570, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,671:INFO:TEST BATCH-110: t = 10.8027, Revenue: 2.164949, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,676:INFO:TEST BATCH-111: t = 10.8065, Revenue: 2.165344, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,680:INFO:TEST BATCH-112: t = 10.8104, Revenue: 2.165755, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,685:INFO:TEST BATCH-113: t = 10.8137, Revenue: 2.166181, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,690:INFO:TEST BATCH-114: t = 10.8166, Revenue: 2.166622, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,695:INFO:TEST BATCH-115: t = 10.8194, Revenue: 2.167077, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,700:INFO:TEST BATCH-116: t = 10.8226, Revenue: 2.167546, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,705:INFO:TEST BATCH-117: t = 10.8255, Revenue: 2.168029, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,709:INFO:TEST BATCH-118: t = 10.8283, Revenue: 2.168526, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,714:INFO:TEST BATCH-119: t = 10.8315, Revenue: 2.169036, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,719:INFO:TEST BATCH-120: t = 10.8344, Revenue: 2.169559, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,724:INFO:TEST BATCH-121: t = 10.8372, Revenue: 2.170094, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,730:INFO:TEST BATCH-122: t = 10.8410, Revenue: 2.170642, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,734:INFO:TEST BATCH-123: t = 10.8438, Revenue: 2.171201, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,739:INFO:TEST BATCH-124: t = 10.8466, Revenue: 2.171772, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,745:INFO:TEST BATCH-125: t = 10.8508, Revenue: 2.172354, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,750:INFO:TEST BATCH-126: t = 10.8555, Revenue: 2.172947, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,755:INFO:TEST BATCH-127: t = 10.8594, Revenue: 2.173550, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,759:INFO:TEST BATCH-128: t = 10.8633, Revenue: 2.174164, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,764:INFO:TEST BATCH-129: t = 10.8672, Revenue: 2.174788, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,768:INFO:TEST BATCH-130: t = 10.8700, Revenue: 2.175421, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,774:INFO:TEST BATCH-131: t = 10.8735, Revenue: 2.176064, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,778:INFO:TEST BATCH-132: t = 10.8764, Revenue: 2.176715, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,783:INFO:TEST BATCH-133: t = 10.8794, Revenue: 2.177375, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,788:INFO:TEST BATCH-134: t = 10.8823, Revenue: 2.178044, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,793:INFO:TEST BATCH-135: t = 10.8858, Revenue: 2.178721, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,798:INFO:TEST BATCH-136: t = 10.8896, Revenue: 2.179406, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,803:INFO:TEST BATCH-137: t = 10.8929, Revenue: 2.180099, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,808:INFO:TEST BATCH-138: t = 10.8959, Revenue: 2.180799, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,813:INFO:TEST BATCH-139: t = 10.8995, Revenue: 2.181506, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,818:INFO:TEST BATCH-140: t = 10.9025, Revenue: 2.182221, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,823:INFO:TEST BATCH-141: t = 10.9061, Revenue: 2.182942, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,828:INFO:TEST BATCH-142: t = 10.9091, Revenue: 2.183671, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,833:INFO:TEST BATCH-143: t = 10.9129, Revenue: 2.184405, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,838:INFO:TEST BATCH-144: t = 10.9161, Revenue: 2.185146, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,843:INFO:TEST BATCH-145: t = 10.9194, Revenue: 2.185893, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,849:INFO:TEST BATCH-146: t = 10.9232, Revenue: 2.186646, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,853:INFO:TEST BATCH-147: t = 10.9261, Revenue: 2.187405, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,858:INFO:TEST BATCH-148: t = 10.9290, Revenue: 2.188169, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,863:INFO:TEST BATCH-149: t = 10.9326, Revenue: 2.188940, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,868:INFO:TEST BATCH-150: t = 10.9355, Revenue: 2.189715, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,873:INFO:TEST BATCH-151: t = 10.9392, Revenue: 2.190496, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,878:INFO:TEST BATCH-152: t = 10.9422, Revenue: 2.191282, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,883:INFO:TEST BATCH-153: t = 10.9452, Revenue: 2.192073, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,887:INFO:TEST BATCH-154: t = 10.9483, Revenue: 2.192869, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,892:INFO:TEST BATCH-155: t = 10.9512, Revenue: 2.193669, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,897:INFO:TEST BATCH-156: t = 10.9548, Revenue: 2.194474, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,903:INFO:TEST BATCH-157: t = 10.9583, Revenue: 2.195285, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,908:INFO:TEST BATCH-158: t = 10.9616, Revenue: 2.196099, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,912:INFO:TEST BATCH-159: t = 10.9646, Revenue: 2.196918, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,917:INFO:TEST BATCH-160: t = 10.9678, Revenue: 2.197741, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,922:INFO:TEST BATCH-161: t = 10.9708, Revenue: 2.198568, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,926:INFO:TEST BATCH-162: t = 10.9736, Revenue: 2.199399, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,932:INFO:TEST BATCH-163: t = 10.9773, Revenue: 2.200235, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,936:INFO:TEST BATCH-164: t = 10.9801, Revenue: 2.201074, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,941:INFO:TEST BATCH-165: t = 10.9834, Revenue: 2.201917, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,946:INFO:TEST BATCH-166: t = 10.9866, Revenue: 2.202764, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,952:INFO:TEST BATCH-167: t = 10.9901, Revenue: 2.203616, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,956:INFO:TEST BATCH-168: t = 10.9930, Revenue: 2.204470, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,962:INFO:TEST BATCH-169: t = 10.9969, Revenue: 2.205329, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,967:INFO:TEST BATCH-170: t = 11.0002, Revenue: 2.206192, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:02,971:INFO:TEST BATCH-171: t = 11.0030, Revenue: 2.207058, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,976:INFO:TEST BATCH-172: t = 11.0059, Revenue: 2.207929, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,980:INFO:TEST BATCH-173: t = 11.0087, Revenue: 2.208803, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:02,985:INFO:TEST BATCH-174: t = 11.0119, Revenue: 2.209682, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,990:INFO:TEST BATCH-175: t = 11.0147, Revenue: 2.210564, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:02,995:INFO:TEST BATCH-176: t = 11.0182, Revenue: 2.211450, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,000:INFO:TEST BATCH-177: t = 11.0220, Revenue: 2.212340, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,006:INFO:TEST BATCH-178: t = 11.0254, Revenue: 2.213234, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,011:INFO:TEST BATCH-179: t = 11.0288, Revenue: 2.214132, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:03,016:INFO:TEST BATCH-180: t = 11.0323, Revenue: 2.215034, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:03,021:INFO:TEST BATCH-181: t = 11.0352, Revenue: 2.215939, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:03,026:INFO:TEST BATCH-182: t = 11.0382, Revenue: 2.216849, Regret: 0.000002, IRP: 0.000000
# 2019-02-02 23:12:03,031:INFO:TEST BATCH-183: t = 11.0416, Revenue: 2.217763, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,035:INFO:TEST BATCH-184: t = 11.0446, Revenue: 2.218680, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:03,040:INFO:TEST BATCH-185: t = 11.0478, Revenue: 2.219601, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,045:INFO:TEST BATCH-186: t = 11.0510, Revenue: 2.220526, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:03,051:INFO:TEST BATCH-187: t = 11.0548, Revenue: 2.221454, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,055:INFO:TEST BATCH-188: t = 11.0577, Revenue: 2.222385, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,060:INFO:TEST BATCH-189: t = 11.0607, Revenue: 2.223318, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,065:INFO:TEST BATCH-190: t = 11.0642, Revenue: 2.224255, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:03,070:INFO:TEST BATCH-191: t = 11.0671, Revenue: 2.225193, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,075:INFO:TEST BATCH-192: t = 11.0709, Revenue: 2.226133, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,080:INFO:TEST BATCH-193: t = 11.0738, Revenue: 2.227074, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,085:INFO:TEST BATCH-194: t = 11.0768, Revenue: 2.228016, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,090:INFO:TEST BATCH-195: t = 11.0801, Revenue: 2.228958, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,094:INFO:TEST BATCH-196: t = 11.0829, Revenue: 2.229899, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:03,099:INFO:TEST BATCH-197: t = 11.0865, Revenue: 2.230840, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,105:INFO:TEST BATCH-198: t = 11.0901, Revenue: 2.231778, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,110:INFO:TEST BATCH-199: t = 11.0933, Revenue: 2.232715, Regret: 0.000001, IRP: 0.000000
# 2019-02-02 23:12:03,114:INFO:TEST BATCH-200: t = 11.0963, Revenue: 2.233649, Regret: 0.000000, IRP: 0.000000
# 2019-02-02 23:12:03,116:INFO:TEST ALL-400000: t = 11.0963, Revenue: 2.133022, Regret: 0.000001, IRP: 0.000000

# %%
alloc = np.load(cfg.dir_name + "/alloc_tst_400000.npy").reshape(D,D,2)
pay = np.load(cfg.dir_name + "/pay_tst_400000.npy").reshape(D,D,1)

# %%
x1 = 4.0/3.0 + np.sqrt(4.0 + 3.0/2.0)/3.0
points1 = [(3.0 - 1.0/3.0, 3.0), (2.0, 2.0 + 1.0/3.0)]                    
points2 = [(2.0, 2 * x1 - 2.0), (2 * x1 - 2.0, 2.0)]                 
points3 = [(2.0 + 1.0/3.0, 2.0), (3.0, 3.0 - 1.0/3.0)]

x_1 = list(map(lambda x: x[0], points1))
y_1 = list(map(lambda x: x[1], points1))
x_2 = list(map(lambda x: x[0], points2))
y_2 = list(map(lambda x: x[1], points2))
x_3 = list(map(lambda x: x[0], points3))
y_3 = list(map(lambda x: x[1], points3))

plt.rcParams.update({'font.size': 10, 'axes.labelsize': 'x-large'})
fig, ax = plt.subplots(ncols = 1, nrows = 1, figsize = (8,6))
ax.plot(x_1, y_1, linewidth = 2, linestyle = '--', color='black')
ax.plot(x_2, y_2, linewidth = 2, linestyle = '--', color='black')
ax.plot(x_3, y_3, linewidth = 2, linestyle = '--', color='black')
img = ax.imshow(alloc[::-1, :, 0], extent=[2,3,2,3], vmin = 0.0, vmax=1.0, cmap = 'YlOrRd')

plt.text(2.2, 2.8, s='0', color='black', fontsize='10', fontweight='bold')
plt.text(2.05, 2.05, s='0', color='black', fontsize='10', fontweight='bold')
plt.text(2.5, 2.5, s='0.5', color='black', fontsize='10', fontweight='bold')
plt.text(2.8, 2.2, s='1', color='black', fontsize='10', fontweight='bold')
                    
ax.set_xlabel('$v_1$')
ax.set_ylabel('$v_2$')
plt.title('Prob. of allocating item 1')

_ = plt.colorbar(img, fraction=0.046, pad=0.04)
if save_plot:
    fig.set_size_inches(4, 3)
    plt.savefig(os.path.join(cfg.dir_name, 'alloc1.pdf'), bbox_inches = 'tight', pad_inches = 0.05)

# %%
x1 = 4.0/3.0 + np.sqrt(4.0 + 3.0/2.0)/3.0
points1 = [(3.0 - 1.0/3.0, 3.0), (2.0, 2.0 + 1.0/3.0)]
points2 = [(2.0, 2 * x1 - 2.0), (2 * x1 - 2.0, 2.0)]
points3 = [(2.0 + 1.0/3.0, 2.0), (3.0, 3.0 - 1.0/3.0)]

x_1 = list(map(lambda x: x[0], points1))
y_1 = list(map(lambda x: x[1], points1))
x_2 = list(map(lambda x: x[0], points2))
y_2 = list(map(lambda x: x[1], points2))
x_3 = list(map(lambda x: x[0], points3))
y_3 = list(map(lambda x: x[1], points3))

plt.rcParams.update({'font.size': 10, 'axes.labelsize': 'x-large'})
fig, ax = plt.subplots(ncols = 1, nrows = 1, figsize = (8,6))

ax.plot(x_1, y_1, linewidth = 2, linestyle = '--', color='black')
ax.plot(x_2, y_2, linewidth = 2, linestyle = '--', color='black')
ax.plot(x_3, y_3, linewidth = 2, linestyle = '--', color='black')
img = ax.imshow(alloc[::-1, :, 1], extent=[2,3,2,3], vmin = 0.0, vmax=1.0, cmap = 'YlOrRd')

plt.text(2.2, 2.8, s='1', color='black', fontsize='10', fontweight='bold')
plt.text(2.05, 2.05, s='0', color='black', fontsize='10', fontweight='bold')
plt.text(2.5, 2.5, s='0.5', color='black', fontsize='10', fontweight='bold')
plt.text(2.8, 2.2, s='0', color='black', fontsize='10', fontweight='bold')
                    
ax.set_xlabel('$v_1$')
ax.set_ylabel('$v_2$')
plt.title('Prob. of allocating item 2')

_ = plt.colorbar(img, fraction=0.046, pad=0.04)
if save_plot:
    fig.set_size_inches(4, 3)
    plt.savefig(os.path.join(cfg.dir_name, 'alloc2.pdf'), bbox_inches = 'tight', pad_inches = 0.05)
